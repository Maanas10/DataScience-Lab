# %%
import matplotlib.pyplot as plt
import numpy as np
 
xpoints = np.array([5, 7, 10, 22, 10, 12, 14])
ypoints = np.array([3, 7, 9, 11, 3, 11, 4])
 
plt.plot(xpoints, ypoints)
plt.show()

# %%
# importing the required module
import matplotlib.pyplot as plt
   
# x axis values
x = [6,10]
# corresponding y axis values
y = [12,14]
   
# plotting the points  
plt.plot(x, y)
   
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
   
# function to show the plot
plt.show()
